# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df= pd.read_csv("C:/Users/isha0/Downloads/student_ml_dataset.csv")

# %%
df.head()
# Out:
#                 Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 0        Derek Smith   26  Female       6.596347   98             68
# 1  Christopher Boyle   37    Male       5.672202  133             44
# 2      Bradley Jones   19    Male       6.282581   89             90
# 3      Eric Martinez   21    Male       8.004422  106             81
# 4   Jennifer Ferrell   29  Female       4.322501   88             41
#
#    Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# 0         100               43               True
# 1          53               92               True
# 2          48               57               True
# 3          88               41              False
# 4          83               85               True

# %%
df.shape
# Out:
# (1000, 9)

# %%
#univariate analysis

# %%
df.Gender.value_counts()
# Out:
# Female    516
# Male      484
# Name: Gender, dtype: int64

# %%
df_Female=df.loc[df['Gender']=='Female']
df_Male=df.loc[df['Gender']=='Male']

# %%
plt.plot(df_Female['Age'],np.zeros_like(df_Female['Age']),'o')
plt.plot(df_Male['Age'],np.zeros_like(df_Male['Age']),'green')

# %%
#bivariate analysis

# %%
sns.FacetGrid(df,hue='Gender',height=5).map(plt.scatter,'Math_Marks','Physics_Marks').add_legend()

# %%
#multivariate analysis

# %%
sns.pairplot(df,hue='Gender',)
